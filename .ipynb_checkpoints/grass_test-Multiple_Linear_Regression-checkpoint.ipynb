# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data1 = pd.DataFrame(pd.read_csv("./italian_testdata.csv"))
data1 = data1.rename(columns ={"건물수량(kg/ha)":"건물수량"})
indx = data1[data1['연도'] <= 1999].index
data1 = data1.drop(indx)

# %%
data1.tail()
# Out:
#       번호          품종  지역    연도   건물수량  연평균기온  최저기온  최고기온  고온일수  연속고온지속일수  \
# 129  130  이탈리안 라이그라스  연천  2005   5513   10.3 -18.0  34.8     7         3
# 130  131  이탈리안 라이그라스  연천  2006   6309   11.2 -17.5  34.8     8         3
# 131  132  이탈리안 라이그라스  천안  2017  12233   11.8 -15.9  35.2     6         3
# 132  133  이탈리안 라이그라스  천안  2016  15271   12.7 -18.6  35.1    17         7
# 133  134  이탈리안 라이그라스  천안  2018  13338   11.8 -20.6  37.8    31        22
#
#         강수량  평균 상대습도(%)  합계 일조시간(hr)  일조율(%)  평균 풍속(m/s)
# 129  1378.2        64.6       2167.7   48.67         1.8
# 130  1360.1        66.6       1972.1   44.27         1.6
# 131  1305.0        64.1       2473.1   55.54         1.5
# 132  1004.8        69.9       2223.8   49.83         1.5
# 133  1163.4        65.3       2396.4   53.81         1.6

# %%
# crim, rm, lstat을 통한 다중 선형회귀분석
x_data = data1[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
target = data1[['건물수량']]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# %%
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   건물수량   R-squared:                       0.451
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     10.11
# Date:                Fri, 06 Nov 2020   Prob (F-statistic):           2.98e-12
# Time:                        02:29:00   Log-Likelihood:                -1300.0
# No. Observations:                 134   AIC:                             2622.
# Df Residuals:                     123   BIC:                             2654.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.612e+04   2.17e+04     -2.129      0.035    -8.9e+04   -3241.481
# ...

# %%
fitted_multi_model.params
# Out:
# const         -46117.005842
# 연평균기온           1860.171290
# 최저기온              45.241559
# 최고기온             932.644054
# 고온일수            -204.411024
# 연속고온지속일수         -48.888117
# 강수량               -0.390926
# 평균 상대습도(%)        98.337237
# 합계 일조시간(hr)      -33.318316
# 일조율(%)          1450.949403
# 평균 풍속(m/s)      -531.978773
# dtype: float64

# %%
x = data1[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
y = data1[['건물수량']]
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = mlr.predict(x_test)

# %%
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
print(mlr.coef_)
# Out:
# [[ 2.17116829e+03  1.78951497e+01  1.68379268e+03 -3.14717862e+02
#   -8.12133858e+01 -1.50156554e-01  1.53577585e+02 -1.72829330e+01
#    8.05901322e+02 -3.09159169e+02]]

# %%
plt.scatter(data1[['연평균기온']], data1[['건물수량']], alpha=0.4)
plt.show()
#

# %%
print(mlr.score(x_train, y_train))
#결정계수
# Out:
# 0.46741336917138077

# %%
data1.corr()
# Out:
#                    번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호           1.000000  0.241454 -0.169756 -0.042416 -0.144150  0.169760
# 연도           0.241454  1.000000  0.029498  0.255483  0.055616  0.492630
# 건물수량        -0.169756  0.029498  1.000000  0.608962  0.622341  0.005632
# 연평균기온       -0.042416  0.255483  0.608962  1.000000  0.896022  0.239541
# 최저기온        -0.144150  0.055616  0.622341  0.896022  1.000000  0.015936
# 최고기온         0.169760  0.492630  0.005632  0.239541  0.015936  1.000000
# 고온일수         0.169042  0.493943 -0.089369  0.248032 -0.033382  0.838736
# 연속고온지속일수     0.163958  0.461551 -0.163525  0.088572 -0.174998  0.773618
# 강수량         -0.082458  0.112199  0.053881  0.041634  0.093927 -0.056474
# 평균 상대습도(%)  -0.031725  0.299597  0.060421  0.049467  0.033123 -0.115580
# 합계 일조시간(hr)  0.218453  0.490974 -0.402258 -0.486974 -0.600410  0.366494
# 일조율(%)       0.216412  0.491458 -0.396908 -0.480432 -0.592002  0.367304
# ...

# %%
data2 = pd.DataFrame(pd.read_csv("./rye_testdata.csv"))
data2 = data2.rename(columns ={"건물수량(kg/ha)":"건물수량"})
indx = data2[data2['연도'] <= 1999].index
data2 = data2.drop(indx)
data2.corr()
# Out:
#                    번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호           1.000000  0.268873  0.296083  0.114939  0.055657  0.059054
# 연도           0.268873  1.000000 -0.114919  0.330737  0.109032  0.360660
# 건물수량         0.296083 -0.114919  1.000000 -0.164086 -0.121840 -0.358295
# 연평균기온        0.114939  0.330737 -0.164086  1.000000  0.791756  0.608991
# 최저기온         0.055657  0.109032 -0.121840  0.791756  1.000000  0.398645
# 최고기온         0.059054  0.360660 -0.358295  0.608991  0.398645  1.000000
# 고온일수         0.042626  0.206224 -0.242360  0.675572  0.340494  0.717355
# 연속고온지속일수     0.077645  0.236031 -0.232085  0.531622  0.240303  0.775648
# 강수량         -0.125070 -0.258468  0.011546 -0.690367 -0.589624 -0.381398
# 평균 상대습도(%)  -0.136216 -0.110223  0.107449 -0.633426 -0.520512 -0.430895
# 합계 일조시간(hr)  0.408223  0.513864  0.036728  0.324220  0.103818  0.372873
# 일조율(%)       0.461059  0.453268  0.020327  0.326131  0.116242  0.381165
# ...

# %%
# crim, rm, lstat을 통한 다중 선형회귀분석
x_data = data2[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
target = data2[['건물수량']]

# for b0, 상수항 추가
x_data2 = sm.add_constant(x_data, has_constant = "add")

# %%
multi_model = sm.OLS(target, x_data2)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   건물수량   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     1.509
# Date:                Fri, 06 Nov 2020   Prob (F-statistic):              0.154
# Time:                        02:29:03   Log-Likelihood:                -748.37
# No. Observations:                  82   AIC:                             1519.
# Df Residuals:                      71   BIC:                             1545.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        4.208e+04   1.59e+04      2.648      0.010    1.04e+04    7.38e+04
# ...

# %%
fitted_multi_model.params
# Out:
# const          42078.235236
# 연평균기온            -28.882285
# 최저기온             -11.801712
# 최고기온            -981.035237
# 고온일수             -16.036311
# 연속고온지속일수          53.809757
# 강수량               -0.738477
# 평균 상대습도(%)       -27.810678
# 합계 일조시간(hr)        3.166728
# 일조율(%)           -61.149193
# 평균 풍속(m/s)       143.577598
# dtype: float64

# %%
x = data2[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
y = data2[['건물수량']]
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = mlr.predict(x_test)

# %%
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
print(mlr.coef_)
# Out:
# [[ 520.77832266  -70.19271723 -709.2269617   -29.19715492   48.83135282
#      1.29953914  -50.92331149    1.82841209  -46.93521456 -552.08720864]]

# %%
plt.scatter(data2[['연평균기온']], data2[['건물수량']], alpha=0.4)
plt.show()
#

# %%
print(mlr.score(x_train, y_train))
#결정계수
# Out:
# 0.14011437818154449

# %%
data3 = pd.DataFrame(pd.read_csv("./forage_barley_testdata.csv"))
data3 = data3.rename(columns ={"건물수량(kg/ha)":"건물수량"})
indx = data3[data3['연도'] <= 1999].index
data3 = data3.drop(indx)
data3.corr()
# Out:
#                    번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호           1.000000  0.984724  0.001026  0.065401 -0.069911  0.292597
# 연도           0.984724  1.000000  0.022263  0.065637 -0.048989  0.309732
# 건물수량         0.001026  0.022263  1.000000  0.207601  0.240502 -0.008498
# 연평균기온        0.065401  0.065637  0.207601  1.000000  0.739602  0.565894
# 최저기온        -0.069911 -0.048989  0.240502  0.739602  1.000000  0.162301
# 최고기온         0.292597  0.309732 -0.008498  0.565894  0.162301  1.000000
# 고온일수         0.126900  0.117030  0.001771  0.547839  0.102256  0.775786
# 연속고온지속일수     0.199020  0.220446 -0.015547  0.433644  0.028374  0.804167
# 강수량         -0.112387 -0.184442 -0.119161 -0.270680 -0.237192 -0.135866
# 평균 상대습도(%)  -0.023609  0.020115 -0.134084 -0.720046 -0.337253 -0.526039
# 합계 일조시간(hr)  0.679546  0.702224 -0.008665  0.017928 -0.178170  0.402085
# 일조율(%)       0.683208  0.704855 -0.011496  0.021775 -0.178722  0.405393
# ...

# %%
# crim, rm, lstat을 통한 다중 선형회귀분석
x_data = data3[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
target = data3[['건물수량']]

# for b0, 상수항 추가
x_data3 = sm.add_constant(x_data, has_constant = "add")

# %%
multi_model = sm.OLS(target, x_data3)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   건물수량   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                 -0.074
# Method:                 Least Squares   F-statistic:                    0.5984
# Date:                Fri, 06 Nov 2020   Prob (F-statistic):              0.807
# Time:                        02:29:06   Log-Likelihood:                -546.37
# No. Observations:                  59   AIC:                             1115.
# Df Residuals:                      48   BIC:                             1138.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        9442.8123   2.66e+04      0.355      0.724    -4.4e+04    6.29e+04
# ...

# %%
fitted_multi_model.params
# Out:
# const          9442.812326
# 연평균기온           515.110902
# 최저기온             35.449489
# 최고기온           -162.232348
# 고온일수            -21.535912
# 연속고온지속일수        -19.457202
# 강수량               0.460396
# 평균 상대습도(%)      -78.289817
# 합계 일조시간(hr)     112.222428
# 일조율(%)        -4895.524959
# 평균 풍속(m/s)      752.477764
# dtype: float64

# %%
x = data3[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
y = data3[['건물수량']]
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = mlr.predict(x_test)

# %%
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
print(mlr.coef_)
# Out:
# [[ 2.63885727e+02  1.32886934e+02 -2.46324930e+02 -2.36720120e+01
#   -1.56835294e+01  7.29665345e-01 -9.52914696e+01  1.00367826e+02
#   -4.36109621e+03  4.58333014e+02]]

# %%
plt.scatter(data3[['연평균기온']], data3[['건물수량']], alpha=0.4)
plt.show()
#

# %%
print(mlr.score(x_train, y_train))
#결정계수
# Out:
# 0.12017469409082715

# %%
data4 = pd.DataFrame(pd.read_csv("./pasture_grass_testdata.csv"))
data4 = data4.rename(columns ={"건물수량(kg/ha)":"건물수량"})
indx = data4[data4['연도'] <= 1999].index
data4 = data4.drop(indx)
data4.corr()
# Out:
#                    번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호           1.000000 -0.233106 -0.044110 -0.642984 -0.580630 -0.525110
# 연도          -0.233106  1.000000  0.294866  0.310165  0.195013  0.479514
# 건물수량        -0.044110  0.294866  1.000000  0.408202  0.398227  0.366174
# 연평균기온       -0.642984  0.310165  0.408202  1.000000  0.889161  0.836945
# 최저기온        -0.580630  0.195013  0.398227  0.889161  1.000000  0.588693
# 최고기온        -0.525110  0.479514  0.366174  0.836945  0.588693  1.000000
# 고온일수        -0.202212  0.410871  0.212400  0.362955  0.056470  0.622794
# 연속고온지속일수    -0.220484  0.488950  0.175447  0.243484 -0.003274  0.500286
# 강수량          0.328768 -0.465667 -0.236651 -0.329026 -0.130319 -0.461885
# 평균 상대습도(%)   0.310536 -0.083841 -0.361474 -0.638843 -0.589923 -0.483789
# 합계 일조시간(hr)  0.454618  0.058330 -0.063409 -0.514000 -0.645990 -0.213562
# 일조율(%)       0.451871  0.045218 -0.052103 -0.508705 -0.663345 -0.183137
# ...

# %%
# crim, rm, lstat을 통한 다중 선형회귀분석
x_data = data4[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
target = data4[['건물수량']]

# for b0, 상수항 추가
x_data4 = sm.add_constant(x_data, has_constant = "add")

# %%
multi_model = sm.OLS(target, x_data4)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   건물수량   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     9.477
# Date:                Fri, 06 Nov 2020   Prob (F-statistic):           5.06e-13
# Time:                        02:29:14   Log-Likelihood:                -2136.6
# No. Observations:                 227   AIC:                             4295.
# Df Residuals:                     216   BIC:                             4333.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.038e+04   1.13e+04      0.915      0.361    -1.2e+04    3.27e+04
# ...

# %%
fitted_multi_model.params
# Out:
# const          10378.978965
# 연평균기온            -21.788737
# 최저기온             356.186795
# 최고기온            -227.134727
# 고온일수             -70.047199
# 연속고온지속일수         269.267610
# 강수량               -0.658253
# 평균 상대습도(%)       -33.044237
# 합계 일조시간(hr)      -31.850060
# 일조율(%)          1732.718073
# 평균 풍속(m/s)       264.142846
# dtype: float64

# %%
x = data4[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
y = data4[['건물수량']]
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = mlr.predict(x_test)

# %%
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
print(mlr.coef_)
# Out:
# [[ 1.60605135e+02  3.34127810e+02 -5.67389236e+02 -6.05444901e+01
#    3.74753805e+02 -4.90243625e-01 -4.30847906e+01 -3.95778811e+01
#    2.08084768e+03  4.07634435e+02]]

# %%
plt.scatter(data4[['연평균기온']], data4[['건물수량']], alpha=0.4)
plt.show()
#

# %%
print(mlr.score(x_train, y_train))
#결정계수
# Out:
# 0.3356370011362584

# %%
data5 = pd.DataFrame(pd.read_csv("./corn_testdata.csv"))
data5 = data5.rename(columns ={"건물수량(kg/ha)":"건물수량"})
indx = data5[data5['연도'] <= 1999].index
data5 = data5.drop(indx)
data5.corr()
# Out:
#                    번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호           1.000000  0.001956 -0.008569 -0.843350 -0.761413 -0.304290
# 연도           0.001956  1.000000  0.163945  0.199105 -0.079775  0.265346
# 건물수량        -0.008569  0.163945  1.000000  0.184841  0.180419  0.294991
# 연평균기온       -0.843350  0.199105  0.184841  1.000000  0.854463  0.457505
# 최저기온        -0.761413 -0.079775  0.180419  0.854463  1.000000  0.292541
# 최고기온        -0.304290  0.265346  0.294991  0.457505  0.292541  1.000000
# 고온일수        -0.395288  0.270059  0.210931  0.556522  0.211889  0.677871
# 연속고온지속일수    -0.282322  0.294325  0.120075  0.436201  0.171688  0.622077
# 강수량          0.095193 -0.423975 -0.255129 -0.428979 -0.328182 -0.224033
# 평균 상대습도(%)   0.559749  0.192536 -0.083077 -0.632146 -0.551279 -0.526978
# 합계 일조시간(hr) -0.304380  0.585022  0.106199  0.415500  0.222733  0.429737
# 일조율(%)      -0.312267  0.587809  0.093258  0.422563  0.231534  0.424444
# ...

# %%
# crim, rm, lstat을 통한 다중 선형회귀분석
x_data = data5[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
target = data5[['건물수량']]

# for b0, 상수항 추가
x_data5 = sm.add_constant(x_data, has_constant = "add")

# %%
multi_model = sm.OLS(target, x_data5)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   건물수량   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     21.54
# Date:                Fri, 06 Nov 2020   Prob (F-statistic):           1.68e-32
# Time:                        02:29:36   Log-Likelihood:                -4220.0
# No. Observations:                 437   AIC:                             8462.
# Df Residuals:                     426   BIC:                             8507.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.944e+04   1.14e+04     -1.706      0.089   -4.18e+04    2955.974
# ...

# %%
fitted_multi_model.params
# Out:
# const         -19437.382051
# 연평균기온            522.946886
# 최저기온             407.294404
# 최고기온             961.373156
# 고온일수             116.673751
# 연속고온지속일수        -203.100628
# 강수량               -2.120715
# 평균 상대습도(%)       263.738615
# 합계 일조시간(hr)      167.993426
# 일조율(%)         -7585.451357
# 평균 풍속(m/s)     -3763.529232
# dtype: float64

# %%
x = data5[['연평균기온', '최저기온', '최고기온', '고온일수', '연속고온지속일수','강수량','평균 상대습도(%)','합계 일조시간(hr)','일조율(%)','평균 풍속(m/s)']]
y = data5[['건물수량']]
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = mlr.predict(x_test)

# %%
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
print(mlr.coef_)
# Out:
# [[ 7.57916984e+02  3.73434580e+02  8.66656468e+02  1.14087928e+02
#   -2.33006959e+02 -1.99145246e+00  2.45115719e+02  1.74344014e+02
#   -7.84097678e+03 -4.43414772e+03]]

# %%
plt.scatter(data5[['연평균기온']], data5[['건물수량']], alpha=0.4)
plt.show()
#

# %%
print(mlr.score(x_train, y_train))
#결정계수
# Out:
# 0.3483948348251241
