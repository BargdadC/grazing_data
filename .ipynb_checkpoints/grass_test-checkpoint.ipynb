# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
data1 = pd.DataFrame(pd.read_csv("./italian_testdata.csv"))
data1 = data1.rename(columns ={"건물수량(kg/ha)":"건물수량"})

# %%
data1.head()
# Out:
#    번호          품종  지역    연도   건물수량  연평균기온  최저기온  최고기온  고온일수  연속고온지속일수     강수량
# 0   1  이탈리안 라이그라스  천안  2006  10668   11.5 -15.6  33.5     6         3  1043.3
# 1   2  이탈리안 라이그라스  제주  2006  18966   16.2  -1.8  34.0     7         2  1527.4
# 2   3  이탈리안 라이그라스  연천  2006   8600   11.2 -17.5  34.8     8         3  1360.1
# 3   4  이탈리안 라이그라스  익산  2006   6193   14.1 -13.1  36.4    28        19  1187.5
# 4   5  이탈리안 라이그라스  천안  2007  16008   12.5 -13.6  34.9     3         2  1562.4

# %%
data1.corr()
# Out:
#                 번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호        1.000000  0.241454 -0.169756 -0.020963 -0.099422  0.059738
# 연도        0.241454  1.000000  0.029498  0.048294  0.089822  0.131209
# 건물수량     -0.169756  0.029498  1.000000  0.239715  0.447601  0.000602
# 연평균기온    -0.020963  0.048294  0.239715  1.000000 -0.400931  0.886411
# 최저기온     -0.099422  0.089822  0.447601 -0.400931  1.000000 -0.653537
# 최고기온      0.059738  0.131209  0.000602  0.886411 -0.653537  1.000000
# 고온일수      0.169042  0.493943 -0.089369  0.183189 -0.104150  0.404122
# 연속고온지속일수  0.163958  0.461551 -0.163525  0.107523 -0.193875  0.366640
# 강수량      -0.082458  0.112199  0.053881 -0.037265  0.118103 -0.076816
#
#               고온일수  연속고온지속일수       강수량
# 번호        0.169042  0.163958 -0.082458
# 연도        0.493943  0.461551  0.112199
# 건물수량     -0.089369 -0.163525  0.053881
# 연평균기온     0.183189  0.107523 -0.037265
# 최저기온     -0.104150 -0.193875  0.118103
# 최고기온      0.404122  0.366640 -0.076816
# 고온일수      1.000000  0.883768 -0.110378
# 연속고온지속일수  0.883768  1.000000 -0.066862
# 강수량      -0.110378 -0.066862  1.000000

# %%
model = smf.ols(formula = '건물수량 ~ 연평균기온', data = data1)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     8.048
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):            0.00528
# Time:                        07:34:37   Log-Likelihood:                -1336.2
# No. Observations:                 134   AIC:                             2676.
# Df Residuals:                     132   BIC:                             2682.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7384.8448   1354.215      5.453      0.000    4706.074    1.01e+04
# 연평균기온        286.7063    101.066      2.837      0.005      86.788     486.625
# ==============================================================================
# Omnibus:                       28.031   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.814
# Skew:                           1.077   Prob(JB):                     1.37e-09
# Kurtosis:                       4.635   Cond. No.                         40.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최저기온', data = data1)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     33.07
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           5.88e-08
# Time:                        07:34:37   Log-Likelihood:                -1325.2
# No. Observations:                 134   AIC:                             2654.
# Df Residuals:                     132   BIC:                             2660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.461e+04    751.124     19.445      0.000    1.31e+04    1.61e+04
# 최저기온         295.0313     51.303      5.751      0.000     193.549     396.513
# ==============================================================================
# Omnibus:                       15.027   Durbin-Watson:                   2.124
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               22.067
# Skew:                           0.587   Prob(JB):                     1.62e-05
# Kurtosis:                       4.605   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최고기온', data = data1)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                 4.781e-05
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.994
# Time:                        07:34:38   Log-Likelihood:                -1340.2
# No. Observations:                 134   AIC:                             2684.
# Df Residuals:                     132   BIC:                             2690.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.098e+04   4313.427      2.545      0.012    2445.152    1.95e+04
# 최고기온           0.8552    123.690      0.007      0.994    -243.815     245.525
# ==============================================================================
# Omnibus:                       32.976   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.762
# Skew:                           1.166   Prob(JB):                     1.28e-12
# Kurtosis:                       5.090   Cond. No.                         324.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 고온일수', data = data1)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.063
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.304
# Time:                        07:34:39   Log-Likelihood:                -1339.7
# No. Observations:                 134   AIC:                             2683.
# Df Residuals:                     132   BIC:                             2689.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.162e+04    752.059     15.449      0.000    1.01e+04    1.31e+04
# 고온일수         -46.7455     45.345     -1.031      0.304    -136.442      42.951
# ==============================================================================
# Omnibus:                       33.939   Durbin-Watson:                   2.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.874
# Skew:                           1.172   Prob(JB):                     1.64e-13
# Kurtosis:                       5.247   Cond. No.                         27.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 연속고온지속일수', data = data1)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     3.627
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):             0.0590
# Time:                        07:34:40   Log-Likelihood:                -1338.4
# No. Observations:                 134   AIC:                             2681.
# Df Residuals:                     132   BIC:                             2687.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.186e+04    640.006     18.528      0.000    1.06e+04    1.31e+04
# 연속고온지속일수    -130.8792     68.725     -1.904      0.059    -266.824       5.066
# ==============================================================================
# Omnibus:                       30.772   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.657
# Skew:                           1.092   Prob(JB):                     1.00e-11
# Kurtosis:                       5.075   Cond. No.                         13.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 강수량', data = data1)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.3843
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.536
# Time:                        07:34:41   Log-Likelihood:                -1340.0
# No. Observations:                 134   AIC:                             2684.
# Df Residuals:                     132   BIC:                             2690.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.023e+04   1340.363      7.630      0.000    7576.221    1.29e+04
# 강수량            0.6279      1.013      0.620      0.536      -1.376       2.631
# ==============================================================================
# Omnibus:                       33.746   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.549
# Skew:                           1.165   Prob(JB):                     1.93e-13
# Kurtosis:                       5.249   Cond. No.                     3.82e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.82e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data2 = pd.DataFrame(pd.read_csv("./rye_testdata.csv"))
data2 = data2.rename(columns ={"건물수량(kg/ha)":"건물수량"})
data2.corr()
# Out:
#                 번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호        1.000000  0.160255  0.298208  0.105805  0.060479  0.043392
# 연도        0.160255  1.000000 -0.122007  0.315997  0.087538  0.358066
# 건물수량      0.298208 -0.122007  1.000000 -0.165482 -0.120315 -0.360157
# 연평균기온     0.105805  0.315997 -0.165482  1.000000  0.789423  0.609582
# 최저기온      0.060479  0.087538 -0.120315  0.789423  1.000000  0.395127
# 최고기온      0.043392  0.358066 -0.360157  0.609582  0.395127  1.000000
# 고온일수      0.024138  0.223010 -0.244507  0.674452  0.336527  0.718405
# 연속고온지속일수  0.061401  0.244633 -0.234305  0.532213  0.237376  0.776759
# 강수량      -0.113696 -0.252622  0.014193 -0.690167 -0.584562 -0.382749
#
#               고온일수  연속고온지속일수       강수량
# 번호        0.024138  0.061401 -0.113696
# 연도        0.223010  0.244633 -0.252622
# 건물수량     -0.244507 -0.234305  0.014193
# 연평균기온     0.674452  0.532213 -0.690167
# 최저기온      0.336527  0.237376 -0.584562
# 최고기온      0.718405  0.776759 -0.382749
# 고온일수      1.000000  0.782982 -0.386332
# 연속고온지속일수  0.782982  1.000000 -0.388173
# 강수량      -0.386332 -0.388173  1.000000

# %%
model = smf.ols(formula = '건물수량 ~ 연평균기온', data = data2)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     2.309
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.132
# Time:                        07:34:41   Log-Likelihood:                -772.61
# No. Observations:                  84   AIC:                             1549.
# Df Residuals:                      82   BIC:                             1554.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.28e+04   2864.787      4.468      0.000    7100.171    1.85e+04
# 연평균기온       -329.2244    216.673     -1.519      0.132    -760.257     101.808
# ==============================================================================
# Omnibus:                       38.483   Durbin-Watson:                   1.332
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              105.171
# Skew:                           1.539   Prob(JB):                     1.45e-23
# Kurtosis:                       7.536   Cond. No.                         144.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최저기온', data = data2)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.204
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.276
# Time:                        07:34:42   Log-Likelihood:                -773.17
# No. Observations:                  84   AIC:                             1550.
# Df Residuals:                      82   BIC:                             1555.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7451.1134    961.045      7.753      0.000    5539.288    9362.938
# 최저기온         -79.1388     72.110     -1.097      0.276    -222.588      64.311
# ==============================================================================
# Omnibus:                       41.680   Durbin-Watson:                   1.328
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.232
# Skew:                           1.651   Prob(JB):                     2.87e-27
# Kurtosis:                       7.902   Cond. No.                         48.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최고기온', data = data2)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     12.22
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           0.000765
# Time:                        07:34:42   Log-Likelihood:                -767.95
# No. Observations:                  84   AIC:                             1540.
# Df Residuals:                      82   BIC:                             1545.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    3.32e+04   7080.520      4.689      0.000    1.91e+04    4.73e+04
# 최고기온        -697.3101    199.461     -3.496      0.001   -1094.102    -300.518
# ==============================================================================
# Omnibus:                       39.000   Durbin-Watson:                   1.294
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.888
# Skew:                           1.502   Prob(JB):                     1.53e-26
# Kurtosis:                       7.994   Cond. No.                     1.01e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 고온일수', data = data2)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     5.214
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):             0.0250
# Time:                        07:34:42   Log-Likelihood:                -771.19
# No. Observations:                  84   AIC:                             1546.
# Df Residuals:                      82   BIC:                             1551.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9254.2553    432.275     21.408      0.000    8394.323    1.01e+04
# 고온일수         -51.0535     22.358     -2.283      0.025     -95.532      -6.575
# ==============================================================================
# Omnibus:                       35.725   Durbin-Watson:                   1.321
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.014
# Skew:                           1.437   Prob(JB):                     6.34e-21
# Kurtosis:                       7.280   Cond. No.                         32.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 연속고온지속일수', data = data2)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     4.763
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):             0.0319
# Time:                        07:34:43   Log-Likelihood:                -771.41
# No. Observations:                  84   AIC:                             1547.
# Df Residuals:                      82   BIC:                             1552.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9184.9343    420.182     21.859      0.000    8349.058       1e+04
# 연속고온지속일수    -114.1424     52.300     -2.182      0.032    -218.183     -10.102
# ==============================================================================
# Omnibus:                       38.528   Durbin-Watson:                   1.203
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.681
# Skew:                           1.545   Prob(JB):                     1.86e-23
# Kurtosis:                       7.513   Cond. No.                         13.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 강수량', data = data2)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                   0.01652
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.898
# Time:                        07:34:43   Log-Likelihood:                -773.77
# No. Observations:                  84   AIC:                             1552.
# Df Residuals:                      82   BIC:                             1556.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8333.3199   1056.907      7.885      0.000    6230.796    1.04e+04
# 강수량            0.1029      0.801      0.129      0.898      -1.490       1.696
# ==============================================================================
# Omnibus:                       41.889   Durbin-Watson:                   1.375
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.817
# Skew:                           1.661   Prob(JB):                     2.14e-27
# Kurtosis:                       7.905   Cond. No.                     5.21e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.21e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data3 = pd.DataFrame(pd.read_csv("./forage_barley_testdata.csv"))
data3 = data3.rename(columns ={"건물수량(kg/ha)":"건물수량"})
data3.corr()
# Out:
#                 번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호        1.000000  0.984724  0.001026  0.065401 -0.069911  0.292597
# 연도        0.984724  1.000000  0.022263  0.065637 -0.048989  0.309732
# 건물수량      0.001026  0.022263  1.000000  0.207601  0.240502 -0.008498
# 연평균기온     0.065401  0.065637  0.207601  1.000000  0.739602  0.565894
# 최저기온     -0.069911 -0.048989  0.240502  0.739602  1.000000  0.162301
# 최고기온      0.292597  0.309732 -0.008498  0.565894  0.162301  1.000000
# 고온일수      0.126900  0.117030  0.001771  0.547839  0.102256  0.775786
# 연속고온지속일수  0.199020  0.220446 -0.015547  0.433644  0.028374  0.804167
# 강수량      -0.112387 -0.184442 -0.119161 -0.270680 -0.237192 -0.135866
#
#               고온일수  연속고온지속일수       강수량
# 번호        0.126900  0.199020 -0.112387
# 연도        0.117030  0.220446 -0.184442
# 건물수량      0.001771 -0.015547 -0.119161
# 연평균기온     0.547839  0.433644 -0.270680
# 최저기온      0.102256  0.028374 -0.237192
# 최고기온      0.775786  0.804167 -0.135866
# 고온일수      1.000000  0.795913 -0.213161
# 연속고온지속일수  0.795913  1.000000 -0.173345
# 강수량      -0.213161 -0.173345  1.000000

# %%
model = smf.ols(formula = '건물수량 ~ 연평균기온', data = data3)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     2.567
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.115
# Time:                        07:34:45   Log-Likelihood:                -548.54
# No. Observations:                  59   AIC:                             1101.
# Df Residuals:                      57   BIC:                             1105.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4150.5384   4505.312      0.921      0.361   -4871.193    1.32e+04
# 연평균기온        539.6775    336.823      1.602      0.115    -134.798    1214.153
# ==============================================================================
# Omnibus:                        9.004   Durbin-Watson:                   2.632
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.914
# Skew:                           0.725   Prob(JB):                       0.0116
# Kurtosis:                       4.233   Cond. No.                         173.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최저기온', data = data3)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     3.499
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):             0.0665
# Time:                        07:34:45   Log-Likelihood:                -548.08
# No. Observations:                  59   AIC:                             1100.
# Df Residuals:                      57   BIC:                             1104.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.36e+04   1250.613     10.871      0.000    1.11e+04    1.61e+04
# 최저기온         184.1593     98.446      1.871      0.067     -12.976     381.294
# ==============================================================================
# Omnibus:                        8.499   Durbin-Watson:                   2.537
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                8.151
# Skew:                           0.710   Prob(JB):                       0.0170
# Kurtosis:                       4.139   Cond. No.                         46.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최고기온', data = data3)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.017
# Method:                 Least Squares   F-statistic:                  0.004117
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.949
# Time:                        07:34:46   Log-Likelihood:                -549.83
# No. Observations:                  59   AIC:                             1104.
# Df Residuals:                      57   BIC:                             1108.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.191e+04   8725.893      1.365      0.178   -5566.438    2.94e+04
# 최고기온         -15.9845    249.126     -0.064      0.949    -514.851     482.882
# ==============================================================================
# Omnibus:                        9.844   Durbin-Watson:                   2.592
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               11.451
# Skew:                           0.672   Prob(JB):                      0.00326
# Kurtosis:                       4.689   Cond. No.                         856.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 고온일수', data = data3)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                 0.0001788
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.989
# Time:                        07:34:46   Log-Likelihood:                -549.83
# No. Observations:                  59   AIC:                             1104.
# Df Residuals:                      57   BIC:                             1108.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.134e+04    536.052     21.159      0.000    1.03e+04    1.24e+04
# 고온일수           0.4231     31.642      0.013      0.989     -62.939      63.785
# ==============================================================================
# Omnibus:                        9.791   Durbin-Watson:                   2.592
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               11.338
# Skew:                           0.671   Prob(JB):                      0.00345
# Kurtosis:                       4.677   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 연속고온지속일수', data = data3)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.017
# Method:                 Least Squares   F-statistic:                   0.01378
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.907
# Time:                        07:34:46   Log-Likelihood:                -549.83
# No. Observations:                  59   AIC:                             1104.
# Df Residuals:                      57   BIC:                             1108.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.139e+04    522.273     21.813      0.000    1.03e+04    1.24e+04
# 연속고온지속일수      -8.7649     74.662     -0.117      0.907    -158.273     140.743
# ==============================================================================
# Omnibus:                        9.741   Durbin-Watson:                   2.587
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.343
# Skew:                           0.663   Prob(JB):                      0.00344
# Kurtosis:                       4.690   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 강수량', data = data3)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8210
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.369
# Time:                        07:34:46   Log-Likelihood:                -549.41
# No. Observations:                  59   AIC:                             1103.
# Df Residuals:                      57   BIC:                             1107.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.253e+04   1356.645      9.239      0.000    9817.292    1.53e+04
# 강수량           -0.9404      1.038     -0.906      0.369      -3.019       1.138
# ==============================================================================
# Omnibus:                        7.457   Durbin-Watson:                   2.588
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                6.984
# Skew:                           0.632   Prob(JB):                       0.0304
# Kurtosis:                       4.115   Cond. No.                     5.00e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data4 = pd.DataFrame(pd.read_csv("./pasture_grass_testdata.csv"))
data4 = data4.rename(columns ={"건물수량(kg/ha)":"건물수량"})
data4.corr()
# Out:
#                 번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호        1.000000 -0.131745 -0.091670 -0.559706 -0.469634 -0.301469
# 연도       -0.131745  1.000000  0.405912  0.309846  0.327309  0.081325
# 건물수량     -0.091670  0.405912  1.000000  0.312566  0.269973  0.045638
# 연평균기온    -0.559706  0.309846  0.312566  1.000000  0.846346  0.665658
# 최저기온     -0.469634  0.327309  0.269973  0.846346  1.000000  0.402720
# 최고기온     -0.301469  0.081325  0.045638  0.665658  0.402720  1.000000
# 고온일수     -0.110537  0.278762  0.079874  0.341834  0.066147  0.705027
# 연속고온지속일수 -0.136432  0.149717  0.015231  0.260731  0.041179  0.658563
# 강수량       0.133011  0.240166  0.100717 -0.142451 -0.097593 -0.372809
#
#               고온일수  연속고온지속일수       강수량
# 번호       -0.110537 -0.136432  0.133011
# 연도        0.278762  0.149717  0.240166
# 건물수량      0.079874  0.015231  0.100717
# 연평균기온     0.341834  0.260731 -0.142451
# 최저기온      0.066147  0.041179 -0.097593
# 최고기온      0.705027  0.658563 -0.372809
# 고온일수      1.000000  0.901164 -0.215728
# 연속고온지속일수  0.901164  1.000000 -0.274740
# 강수량      -0.215728 -0.274740  1.000000

# %%
model = smf.ols(formula = '건물수량 ~ 연평균기온', data = data4)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     68.76
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           6.66e-16
# Time:                        07:34:47   Log-Likelihood:                -6083.7
# No. Observations:                 637   AIC:                         1.217e+04
# Df Residuals:                     635   BIC:                         1.218e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3384.9536    682.895      4.957      0.000    2043.949    4725.959
# 연평균기온        469.4741     56.619      8.292      0.000     358.292     580.656
# ==============================================================================
# Omnibus:                       17.249   Durbin-Watson:                   0.607
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.036
# Skew:                           0.410   Prob(JB):                     0.000121
# Kurtosis:                       3.075   Cond. No.                         61.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최저기온', data = data4)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     49.92
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           4.22e-12
# Time:                        07:34:47   Log-Likelihood:                -6092.3
# No. Observations:                 637   AIC:                         1.219e+04
# Df Residuals:                     635   BIC:                         1.220e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.114e+04    340.014     32.749      0.000    1.05e+04    1.18e+04
# 최저기온         154.6962     21.895      7.065      0.000     111.701     197.691
# ==============================================================================
# Omnibus:                       18.858   Durbin-Watson:                   0.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.761
# Skew:                           0.425   Prob(JB):                     5.12e-05
# Kurtosis:                       3.144   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최고기온', data = data4)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.325
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.250
# Time:                        07:34:47   Log-Likelihood:                -6115.7
# No. Observations:                 637   AIC:                         1.224e+04
# Df Residuals:                     635   BIC:                         1.224e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5906.9730   2634.756      2.242      0.025     733.084    1.11e+04
# 최고기온          88.8061     77.140      1.151      0.250     -62.674     240.286
# ==============================================================================
# Omnibus:                       27.661   Durbin-Watson:                   0.566
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.155
# Skew:                           0.526   Prob(JB):                     2.83e-07
# Kurtosis:                       3.168   Cond. No.                         635.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 고온일수', data = data4)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.077
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):             0.0439
# Time:                        07:34:47   Log-Likelihood:                -6114.4
# No. Observations:                 637   AIC:                         1.223e+04
# Df Residuals:                     635   BIC:                         1.224e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8652.2578    199.414     43.388      0.000    8260.666    9043.849
# 고온일수          40.3978     20.007      2.019      0.044       1.110      79.685
# ==============================================================================
# Omnibus:                       28.823   Durbin-Watson:                   0.571
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.574
# Skew:                           0.538   Prob(JB):                     1.39e-07
# Kurtosis:                       3.177   Cond. No.                         14.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 연속고온지속일수', data = data4)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1473
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):              0.701
# Time:                        07:34:47   Log-Likelihood:                -6116.3
# No. Observations:                 637   AIC:                         1.224e+04
# Df Residuals:                     635   BIC:                         1.225e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8887.0481    190.538     46.642      0.000    8512.887    9261.210
# 연속고온지속일수      13.8586     36.105      0.384      0.701     -57.040      84.758
# ==============================================================================
# Omnibus:                       31.563   Durbin-Watson:                   0.566
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.929
# Skew:                           0.562   Prob(JB):                     2.60e-08
# Kurtosis:                       3.228   Cond. No.                         7.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 강수량', data = data4)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     6.507
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):             0.0110
# Time:                        07:34:48   Log-Likelihood:                -6113.1
# No. Observations:                 637   AIC:                         1.223e+04
# Df Residuals:                     635   BIC:                         1.224e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7841.4827    451.661     17.361      0.000    6954.553    8728.412
# 강수량            0.8426      0.330      2.551      0.011       0.194       1.491
# ==============================================================================
# Omnibus:                       42.685   Durbin-Watson:                   0.578
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.513
# Skew:                           0.655   Prob(JB):                     1.77e-11
# Kurtosis:                       3.389   Cond. No.                     4.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data5 = pd.DataFrame(pd.read_csv("./corn_testdata.csv"))
data5 = data5.rename(columns ={"건물수량(kg/ha)":"건물수량"})
data5.corr()
# Out:
#                 번호        연도      건물수량     연평균기온      최저기온      최고기온  \
# 번호        1.000000  0.001956 -0.008569 -0.843350 -0.761413 -0.304290
# 연도        0.001956  1.000000  0.163945  0.199105 -0.079775  0.265346
# 건물수량     -0.008569  0.163945  1.000000  0.184841  0.180419  0.294991
# 연평균기온    -0.843350  0.199105  0.184841  1.000000  0.854463  0.457505
# 최저기온     -0.761413 -0.079775  0.180419  0.854463  1.000000  0.292541
# 최고기온     -0.304290  0.265346  0.294991  0.457505  0.292541  1.000000
# 고온일수     -0.395288  0.270059  0.210931  0.556522  0.211889  0.677871
# 연속고온지속일수 -0.282322  0.294325  0.120075  0.436201  0.171688  0.622077
# 강수량       0.095193 -0.423975 -0.255129 -0.428979 -0.328182 -0.224033
#
#               고온일수  연속고온지속일수       강수량
# 번호       -0.395288 -0.282322  0.095193
# 연도        0.270059  0.294325 -0.423975
# 건물수량      0.210931  0.120075 -0.255129
# 연평균기온     0.556522  0.436201 -0.428979
# 최저기온      0.211889  0.171688 -0.328182
# 최고기온      0.677871  0.622077 -0.224033
# 고온일수      1.000000  0.723662 -0.287972
# 연속고온지속일수  0.723662  1.000000 -0.228920
# 강수량      -0.287972 -0.228920  1.000000

# %%
model = smf.ols(formula = '건물수량 ~ 연평균기온', data = data5)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     15.39
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           0.000102
# Time:                        07:34:48   Log-Likelihood:                -4301.8
# No. Observations:                 437   AIC:                             8608.
# Df Residuals:                     435   BIC:                             8616.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.028e+04   2107.430      4.880      0.000    6141.729    1.44e+04
# 연평균기온        645.8221    164.635      3.923      0.000     322.244     969.400
# ==============================================================================
# Omnibus:                        1.980   Durbin-Watson:                   0.483
# Prob(Omnibus):                  0.372   Jarque-Bera (JB):                2.033
# Skew:                          -0.160   Prob(JB):                        0.362
# Kurtosis:                       2.906   Cond. No.                         124.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최저기온', data = data5)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     14.64
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           0.000149
# Time:                        07:34:48   Log-Likelihood:                -4302.2
# No. Observations:                 437   AIC:                             8608.
# Df Residuals:                     435   BIC:                             8617.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.144e+04    797.297     26.890      0.000    1.99e+04     2.3e+04
# 최저기온         188.9845     49.399      3.826      0.000      91.895     286.074
# ==============================================================================
# Omnibus:                        0.381   Durbin-Watson:                   0.489
# Prob(Omnibus):                  0.827   Jarque-Bera (JB):                0.470
# Skew:                          -0.063   Prob(JB):                        0.790
# Kurtosis:                       2.900   Cond. No.                         59.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 최고기온', data = data5)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     41.46
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           3.19e-10
# Time:                        07:34:49   Log-Likelihood:                -4289.5
# No. Observations:                 437   AIC:                             8583.
# Df Residuals:                     435   BIC:                             8591.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.148e+04   6212.825     -3.457      0.001   -3.37e+04   -9264.425
# 최고기온        1112.9783    172.848      6.439      0.000     773.258    1452.699
# ==============================================================================
# Omnibus:                        0.628   Durbin-Watson:                   0.506
# Prob(Omnibus):                  0.730   Jarque-Bera (JB):                0.734
# Skew:                          -0.076   Prob(JB):                        0.693
# Kurtosis:                       2.868   Cond. No.                     1.05e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 고온일수', data = data5)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     20.26
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           8.71e-06
# Time:                        07:34:49   Log-Likelihood:                -4299.5
# No. Observations:                 437   AIC:                             8603.
# Df Residuals:                     435   BIC:                             8611.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.691e+04    415.722     40.680      0.000    1.61e+04    1.77e+04
# 고온일수          87.6426     19.474      4.501      0.000      49.368     125.917
# ==============================================================================
# Omnibus:                        1.735   Durbin-Watson:                   0.485
# Prob(Omnibus):                  0.420   Jarque-Bera (JB):                1.518
# Skew:                          -0.129   Prob(JB):                        0.468
# Kurtosis:                       3.129   Cond. No.                         40.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 연속고온지속일수', data = data5)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     6.364
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):             0.0120
# Time:                        07:34:50   Log-Likelihood:                -4306.2
# No. Observations:                 437   AIC:                             8616.
# Df Residuals:                     435   BIC:                             8625.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.777e+04    366.612     48.465      0.000     1.7e+04    1.85e+04
# 연속고온지속일수      98.4387     39.023      2.523      0.012      21.742     175.135
# ==============================================================================
# Omnibus:                        2.242   Durbin-Watson:                   0.476
# Prob(Omnibus):                  0.326   Jarque-Bera (JB):                2.027
# Skew:                          -0.156   Prob(JB):                        0.363
# Kurtosis:                       3.117   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula = '건물수량 ~ 강수량', data = data5)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   건물수량   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     30.29
# Date:                Fri, 16 Oct 2020   Prob (F-statistic):           6.38e-08
# Time:                        07:34:51   Log-Likelihood:                -4294.7
# No. Observations:                 437   AIC:                             8593.
# Df Residuals:                     435   BIC:                             8602.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.315e+04    870.558     26.590      0.000    2.14e+04    2.49e+04
# 강수량           -3.8616      0.702     -5.503      0.000      -5.241      -2.482
# ==============================================================================
# Omnibus:                        1.454   Durbin-Watson:                   0.501
# Prob(Omnibus):                  0.483   Jarque-Bera (JB):                1.494
# Skew:                          -0.138   Prob(JB):                        0.474
# Kurtosis:                       2.926   Cond. No.                     5.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
